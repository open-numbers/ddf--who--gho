# %%
import pandas as pd
import xmltodict
import requests
import os
import numpy as np
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
import ddf_utils.ddf_reader as ddf
from ddf_utils.str import to_concept_id

# %% [markdown]
# # get all meta data

# %%
api = 'http://apps.who.int/gho/athena/api/'

# %%
xml = requests.get(api)

# %%
xml = xml.content

# %%
p = xmltodict.parse(xml)

# %%
p['GHO']['Metadata']['Attribute'][0]
# Out:
# OrderedDict([('@Label', 'COMMENT'),
#              ('@EntityType', 'CORE_DIMENSION'),
#              ('@Entity', 'DATASOURCE'),
#              ('Display', 'COMMENT')])

# %% [markdown]
# # get all indicators

# %%
inds = 'http://apps.who.int/gho/athena/api/GHO/'
xml = requests.get(inds)
xml = xml.content

# %%
indi = xmltodict.parse(xml)

# %%
indi_list = []

for i in indi['GHO']['Metadata']['Dimension']['Code']:
#     print(i)
    indi_list.append(i['@Label'])

# %%
len(indi_list)
# Out:
# 2186

# %%
for i in indi_list:
    
    if os.path.exists('source/{}.csv'.format(i)):
        
#         try:
#             df = pd.read_csv('source/{}.csv'.format(i))
#         except:
#             print(i)
#             continue
#         if 'Unnamed: 0' in df.columns:
#             df.drop('Unnamed: 0', axis=1).to_csv('source/{}.csv'.format(i), index=False)
        
        continue
    
    url = 'http://apps.who.int/gho/athena/api/GHO/{}.csv'.format(i)

    print(url)
#     try:
#         df = pd.read_csv(url)
#     except KeyboardInterrupt:
#         break
#     except:
#         print(url)
#         continue


    
#     df.to_csv('source/{}.csv'.format(i), index=False)
# Out:
# http://apps.who.int/gho/athena/api/GHO/MORT_200.csv
# http://apps.who.int/gho/athena/api/GHO/GHE_DALYNUM.csv

# %%
indi['GHO']['Metadata']['Dimension']['Code'][32]
# Out:
# OrderedDict([('@Label', 'GBD_0000000037'),
#              ('@DisplaySequence', '37'),
#              ('@URL',
#               'http://apps.who.int/gho/indicatorregistry/App_Main/view_indicator.aspx?iid='),
#              ('Attr',
#               OrderedDict([('@Category', 'CATEGORY'),
#                            ('Value',
#                             OrderedDict([('Display',
#                                           'Mortality and global health estimates')]))])),
#              ('Display', 'GBD - population')])

# %%
indi_desc_list = []

for i in indi['GHO']['Metadata']['Dimension']['Code']:
    indi_desc_list.append(i['Display'])

# %%
indi_desc_list
# Out:
# ['Infant mortality rate (probability of dying between birth and age 1 per 1000 live births)',
#  'Adolescent birth rate (per 1000 women aged 15-19 years)',
#  'Contraceptive prevalence (%)',
#  'Unmet need for family planning (%)',
#  'Under-five mortality rate (probability of dying by age 5 per 1000 live births)',
#  'Median availability of selected generic medicines (%) - Public',
#  'Median consumer price ratio of selected generic medicines - Public',
#  'Antiretroviral therapy coverage among people with advanced HIV infection (%)',
#  'Children aged <5 years sleeping under insecticide-treated nets (%)',
#  'Children aged <5 years with fever who received treatment with any antimalarial (%)',
#  'Prevalence of condom use by adults during higher-risk sex (15-49) (%)',
#  'Deaths due to malaria (per 100 000 population)',
#  'Deaths due to tuberculosis among HIV-negative people (per 100 000 population)',
#  'Deaths due to tuberculosis among HIV-positive people (per 100 000 population)',
#  'Prevalence of HIV among adults aged >=15 years (per 100 000 population)',
#  'Incidence of tuberculosis (per 100 000 population per year)',
#  'Population aged 15-24 years with comprehensive correct knowledge of HIV/AIDS (%)',
#  'Tuberculosis detection rate under DOTS (%)',
#  'Prevalence of tuberculosis (per 100 000 population)',
#  'Tuberculosis treatment success under DOTS (%)',
#  'Births attended by skilled health personnel (%)',
#  'Maternal mortality ratio (per 100 000 live births)',
#  'Children aged <5 years stunted (%)',
#  'Population below minimum level of dietary energy consumption',
#  'nMx - age-specific death rate between ages x and x+n',
#  'nqx - probability of dying between ages x and x+n',
#  'lx - number of people left alive at age x',
#  'ndx - number of people dying between ages x and x+n',
#  'nLx - person-years lived between ages x and x+n',
#  'Tx - person-years lived above age x',
#  'ex - expectation of life at age x',
#  'Number of deaths',
#  'GBD - population',
#  'GBD - crude death rate',
#  'Cholera - number of reported cases',
#  'Diphtheria - number of reported cases',
#  'Japanese encephalitis - number of reported cases',
#  'Pertussis - number of reported cases',
#  'Leprosy - number of reported cases',
#  'Total tetanus - number of reported cases',
#  'Meningitis - number of reported cases',
#  'Malaria - number of reported confirmed cases',
#  'Poliomyelitis - number of reported cases',
#  'Yellow fever - number of reported cases',
#  'H5N1 influenza - number of reported cases',
#  'Plague - number of reported cases',
#  'Mumps - number of reported cases',
#  'Number of reported cases of tuberculosis (DOTS)',
#  'Congenital Rubella Syndrome - number of reported cases',
#  'Neonatal tetanus - number of reported cases',
#  'Rubella - number of reported cases',
#  'Mortality - deaths (country)',
#  'Mortality - population (country)',
#  'Mortality - crude death rate per 100 000 population',
#  'Measles - number of reported cases',
#  'Mortality - live births (country)',
#  'Life expectancy at birth (years)',
#  'Healthy life expectancy (HALE) at birth (years)',
#  'Neonatal mortality rate (per 1000 live births)',
#  'Adult mortality rate (probability of dying between 15 and 60 years per 1000 population)',
#  'Low-birth-weight newborns (%)',
#  'Infants exclusively breastfed for the first six months of life (%)',
#  'GBD - Disability-adjusted life years (DALYS)',
#  'GBD - Years of life lost (YLL)',
#  'GBD - Years lost due to disability (YLD)',
#  'Children aged <5 years underweight (%)',
#  'Prevalence of current tobacco use among adolescents (13-15 years) (%)',
#  'Children aged <5 years overweight (%)',
#  'Adults aged &#8805; 20 years who are obese (%)',
#  'Alcohol consumption among adults aged &#8805; 15 years (litres of pure alcohol per person per year)',
#  'Prevalence of smoking any tobacco product among adults (&#8805;15 years) (%)',
#  'Literacy rate among adults aged >= 15 years (%)',
#  'Population (in thousands) total',
#  'Net primary school enrolment ratio (%)',
#  'Population median age (years)',
#  'Population proportion under 15 (%)',
#  'Population living on <$1 (PPP int. $) a day (%)',
#  'Civil registration coverage of births (%)',
#  'Population proportion over 60 (%)',
#  'Gross national income per capita (PPP int. $)',
#  'Civil registration coverage of causes of deaths (%)',
#  'Total fertility rate (per woman)',
#  'Population living in urban areas (%)',
#  'Annual population growth rate (%)',
#  'Antiretroviral therapy coverage among HIV-infected pregnant women for PMTCT (%)',
#  'Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage among 1-year-olds (%)',
#  'Median availability of selected generic medicines (%) - Private',
#  'Hospital beds (per 10 000 population)',
#  'Private prepaid plans as a percentage of private expenditure on health',
#  'Per capita government expenditure on health at average exchange rate (US$)',
#  'Per capita total expenditure on health (PPP int. $)',
#  'Children aged <5 years with ARI symptoms taken to a health facility (%)',
#  'Children aged <5 years with diarrhoea receiving ORT (%)',
#  'Per capita government expenditure on health (PPP int. $)',
#  'Measles (MCV) immunization coverage among 1-year-olds (%)',
#  'Antenatal care coverage - at least one visit (%)',
#  'General government expenditure on health as a percentage of total government expenditure',
#  'Births by caesarean section (%)',
#  'Median consumer price ratio of selected generic medicines - Private',
#  'Hepatitis B (HepB3) immunization coverage among 1-year-olds (%)',
#  'External resources for health as a percentage of total expenditure on health',
#  'Population using improved drinking-water sources (%)',
#  'Number of dentistry personnel',
#  'Children aged 6-59 months who received vitamin A supplementation (%)',
#  'Physicians density (per 10 000 population)',
#  'Distribution of years of life lost by major cause group',
#  'Number of nursing and midwifery personnel',
#  'Neonates protected at birth against neonatal tetanus (PAB) (%)',
#  'Hib (Hib3) immunization coverage among 1-year-olds (%)',
#  'Age-standardized mortality rate by cause (per 100 000 population)',
#  'Social security expenditure on health as a percentage of general government expenditure on health',
#  'Number of physicians',
#  'Deaths due to HIV/AIDS (per 100 000 population)',
#  'Out-of-pocket expenditure as a percentage of private expenditure on health',
#  'Number of community health workers',
#  'Total expenditure on health as a percentage of gross domestic product',
#  'Dentistry personnel density (per 10 000 population)',
#  'Private expenditure on health as a percentage of total expenditure on health',
#  'Nursing and midwifery personnel density (per 10 000 population)',
#  'General government expenditure on health as a percentage of total expenditure on health',
#  'Community health workers density (per 10 000 population)',
#  'Deaths due to malaria (per 100 000 population)',
#  'Antenatal care coverage - at least four visits (%)',
#  'Distribution of causes of death among children aged <5 years (%)',
#  'Per capita total expenditure on health at average exchange rate (US$)',
#  'Number of other health service providers',
#  'Population using improved sanitation facilities (%)',
#  'Other health service providers density (per 10 000 population)',
#  'Age-standardized mortality rate by cause (per 100 000 population) - Cancer',
#  'Age-standardized mortality rate by cause (per 100 000 population) - Cardiovascular',
#  'Age-standardized mortality rate by cause (per 100 000 population) - Injuries',
#  'Age-standardized mortality rate by cause (per 100 000 population) - Noncommunicable',
#  'Distribution of causes of death among children aged <5 years (%) - Malaria',
#  'Distribution of causes of death among children aged <5 years (%) - Pneumonia',
#  'Distribution of causes of death among children aged <5 years (%) - Injuries',
#  'Distribution of causes of death among children aged <5 years (%) - Diarrhoea',
#  'Distribution of causes of death among children aged <5 years (%) - Measles',
#  'Distribution of causes of death among children aged <5 years (%) - Causes arising in the perinatal period',
#  'Distribution of causes of death among children aged <5 years (%) - HIV/AIDS',
#  'Distribution of causes of death among children aged <5 years (%) - Other diseases',
#  'Distribution of years of life lost by broader causes (%) - Communicable',
#  'Distribution of years of life lost by broader causes (%) - Noncommunicable',
#  'Distribution of years of life lost by broader causes (%) - Injuries',
#  'Access to improved drinking water sources',
#  'Access to improved sanitation',
#  'Donor commitments (Million, constant 2009 US$)',
#  'Commitments to recipient countries (Million, constant 2009 US$)',
#  'Donor disbursements (Million, constant 2009 US$)',
#  'Disbursements to recipient countries (Million, constant 2009 US$)',
#  'Prevalence (in thousands)',
#  'Incidence (in thousands)',
#  'Death rates  (per 100,000)',
#  'DALY rates (per 100,000)',
#  'Age-standardized DALYs (per 100,000)',
#  'Monitor',
#  'Protect from tobacco smoke',
#  'Offer help to quit tobacco use',
#  'Warn about the dangers of tobacco',
#  'Enforce bans on tobacco advertising',
#  'Raise taxes on tobacco',
#  'Prevalence of smoking any tobacco product among persons aged >= 15 years',
#  'Daily smoking of any tobacco product (age-standardized rate)',
#  'Current smoking of cigarettes (age-standardized rate)',
#  'Daily smoking of cigarettes (age-standardized rate)',
#  'Health-care facilities (national legislation)',
#  'Education facilities except universities (national legislation)',
#  'Universities (national legislation)',
#  'Government facilities (national legislation)',
#  'Indoor offices (national legislation)',
#  'Restaurants (national legislation)',
#  'Pubs and bars (national legislation)',
#  'Public transport (national legislation)',
#  'All other indoor public places (national legislation)',
#  'Number of places smoke-free (national legislation)',
#  'Compliance with regulations on smoke-free environments (national legislation)',
#  'Subnational smoke-free legislation authority exists',
#  'Comprehensive bans in place subnationally',
#  'Fines for violations',
#  'Fines on the establishment',
#  'Fines on the patron',
#  'Dedicated funds for enforcement',
#  'Citizen complaints and investigations',
#  'Number of reported cases of cholera',
#  'Number of reported deaths from cholera',
#  'Cholera case fatality rate',
#  'Total microscopy examined',
#  'Total microscopy positive',
#  'Suspected malaria cases',
#  'Malaria outpatient cases',
#  'Number of reported presumed and confirmed malaria cases',
#  'Number of health facility reports received per year (Outpatient)',
#  'Number of health facilities (Outpatient)',
#  'Number of reports expected per health facility per year (Outpatient)',
#  'Number of Admin 2 reports received per year (Outpatient)',
#  'Number of Admin 2 units (Outpatient)',
#  'Number of reports expected per Admin 2 per year (Outpatient)',
#  'Cases at community level (presumed and confirmed)',
#  'Number of malaria cases treated with ACT in public facilities',
#  'Number of RDTs delivered (public facilities and community)',
#  'Number of malaria cases treated with ACT (Community level)',
#  'Number of health facility reports received per year (Inpatient)',
#  'Number of health facilities (Inpatient)',
#  'Number of reports expected per health facility per year (Inpatient)',
#  'Number of Admin 2 reports received per year (Inpatient)',
#  'Number of Admin 2 units (Inpatient)',
#  'Number of reports expected per Admin 2 per year (Inpatient)',
#  'Imported cases',
#  'All-cause outpatient cases',
#  'All-cause inpatient cases',
#  'All-cause inpatient deaths',
#  'Malaria inpatient cases',
#  'Malaria attributed deaths',
#  'All-cause deaths (including malaria death) (Vital registration)',
#  'Malaria deaths (including confirmed deaths) (Vital registration)',
#  'Total RDT examined',
#  'Total RDT positive',
#  'Number of P. falciparum',
#  'Number of P. vivax',
#  'Number of mixed infections',
#  'RDT Positive cases at community level',
#  'Microscopy slides/RDTs examined',
#  'Microscopy slides/RDTs positive',
#  'RDT tested at community level',
#  'Examined (by microscopy and RDT)(Active case detection)',
#  'Positive (by microscopy and RDT)(Active case detection)',
#  'Number of P. falciparum (RDT test)',
#  'Number of other plamodium species (RDT test)',
#  'ANC first attendance',
#  'IPT 1st dose',
#  'IPT 2nd dose',
#  'Total number of conventional Insecticide Treated Nets (ITNs) + LLINS sold or delivered',
#  'Total number of Long Lasting Insecticide Treated Nets (LLINs) sold or delivered',
#  'Number distributed through mass campaign',
#  'Number distributed through ANC',
#  'Number distributed through EPI',
#  'Number distributed through other channels',
#  'Number of conventional insecticide-treated nets (ITNs) sold or delivered',
#  'Spraying cycle',
#  'Number of households sprayed at least once',
#  'Number of households targeted for spraying',
#  'Number people targeted for protection by IRS',
#  'Number of people protected by IRS',
#  'Number of houses or structures targeted',
#  'Number of houses or structures sprayed at least once',
#  'Insecticide used',
#  'Number of ACT only treatment doses received (public facilities and community)',
#  'Number of ACT only treatment doses received (public facilities only)',
#  'Total number of ACT treatment courses distributed',
#  'Total number of 1st line treatment course distributed',
#  'Programme Management (PM)',
#  'Entomology and vector control (ITN, IRS, others)',
#  'Surveillance, Monitoring and Evaluation (SME)',
#  'Diagnosis and case manangement (incl. IPT)',
#  'Communications and Advocacy (CAD)',
#  'Training',
#  'Government health budget (USD)',
#  'Government budget for malaria (USD)',
#  'Contributions from the Global Fund (USD)',
#  'Contributions from the Wolrdbank (USD)',
#  'European Union (USD)',
#  'Gov. expenditure on malaria (USD)',
#  'Other (NGOs, foundations,etc)',
#  'Others',
#  'WHO',
#  'UNICEF',
#  'Other UN agencies',
#  'PMI',
#  'Other bilaterals',
#  'High endemic or risk areas ( RMI > 1)',
#  'Low endemic or epidemic-prone areas ( RMI < 1)',
#  'Malaria-free areas (no indigenous transmission)',
#  'Household Net Possession - Percentage with at least one (Any type of mosquito net )',
#  'Household Net Possession - Percentage with more than one (Any type of mosquito net )',
#  'Household Net Possession - Average number of nets per household (Any type of mosquito net )',
#  'Household Net Possession - Percentage with at least one (Ever treated mosquito net )',
#  'Household Net Possession - Percentage with more than one (Ever treated mosquito net )',
#  'Household Net Possession - Average number of ever treated nets per household (Ever treated mosquito net )',
#  'Household Net Possession - Percentage with at least one (Insecticide treated mosquito nets (ITNs) )',
#  'Household Net Possession - Percentage with more than one (Insecticide treated mosquito nets (ITNs) )',
#  'Household Net Possession - Average number of ITNs per household (Insecticide treated mosquito nets (ITNs) )',
#  'Household Net Possession - (Number of households )',
#  'IPT and Anti-malarial Treatment - Percentage who took 2+ doses SP/Fansidar',
#  'Prompt Treatment - Percentage who took antimalarial drugs (Among children under age five with fever)',
#  'Prompt Treatment - Percentage who took antimalarial drugs same or next day (Among children under age five with fever)',
#  'Children with fever - Percentage of children who took drug: SP/ Fansidar',
#  'Children with fever - Percentage of children who took drug: Chloroquine',
#  'Children with fever - Percentage of children who took drug: Combination with artemisinin',
#  'Children with fever - Percentage of children who took drug the same or next day: SP/ Fansidar',
#  'Children with fever - Percentage of children who took drug the same or next day: Chloroquine',
#  'Children with fever - Percentage of children who took drug the same or next day: Combination with artemisinin',
#  'Use of mosquito nets - Percentage of under 5 who slept under any net last night',
#  'Use of mosquito nets - Percentage of under 5 who slept under an ever treated net last night',
#  'Use of mosquito nets - Percentage of under 5 who slept under an ITN last night',
#  'Use of mosquito nets - Number of children under 5',
#  'Use of mosquito nets - Percentage of all women age 15-49 who Slept under any net last night',
#  'Use of mosquito nets - Percentage of all women age 15-49 who Slept under an ever treated net last night',
#  'Use of mosquito nets - Percentage of all women age 15-49 who Slept under an ITN last night',
#  'Use of mosquito nets - Number of pregnant women',
#  'Use of mosquito nets - Percentage of pregnant women age 15-49 who Slept under any net last night',
#  'Use of mosquito nets - Percentage of pregnant women age 15-49 who Slept under an ever treated net last night',
#  'Use of mosquito nets - Percentage of pregnant women age 15-49 who Slept under an ITN last night',
#  'Population',
#  'Treatment success rate (new smear-positive cases)',
#  'Mortality of TB cases (all forms, excluding HIV) per 100 000 population',
#  'Number of deaths from TB (all forms, excluding HIV)',
#  'Current smoking of any tobacco product (crude rate)',
#  'Daily smoking of any tobacco product (crude rate)',
#  'Current smoking of cigarettes (crude rate)',
#  'Daily smoking of cigarettes (crude rate)',
#  'Current users of any smokeless tobacco product (crude rate)',
#  'Daily users of any smokeless tobacco product (crude rate)',
#  'Ever users of any smokeless tobacco product (crude rate)',
#  'Prevalence of current tobacco use among adolescents aged 13-15 years',
#  'Current smokers of cigarettes (youth rate)',
#  'Exposure to smoke at home',
#  'Exposure to smoke outside home',
#  'Jurisdiction name',
#  'Number of people covered by subnational legislation',
#  'Proportion of national population covered by subnational legislation',
#  'Number of places smoke-free (subnational legislation)',
#  'Health-care facilities (subnational legislation)',
#  'Education facilities, except universities (subnational legislation)',
#  'Universities (subnational legislation)',
#  'Government facilities  (subnational legislation)',
#  'Indoor offices (subnational legislation)',
#  'Restaurants (subnational legislation)',
#  'Pubs and bars (subnational legislation)',
#  'Public transport (subnational legislation)',
#  'All other indoor public places (subnational legislation)',
#  'Access to a toll-free quit line',
#  'Smoking cessation support is available in hospitals',
#  'Smoking cessation support is available in health clinics or other primary care facilities',
#  'Smoking cessation support is available in offices of health professionals',
#  'Smoking cessation support is available in the community',
#  'Smoking cessation support is available in other settings',
#  'Nicotine replacement therapy - legally sold',
#  'Nicotine replacement therapy - place available',
#  'Bupropion - legally sold',
#  'Bupropion - place available',
#  'Varenicline - legally sold',
#  'Varenicline - place available',
#  'Ban on deceitful terms on cigarette packaging',
#  'Percentage of principal display area mandated to be covered by health warnings - front and back of cigarette packaging',
#  'Percentage of principal display area mandated to be covered by health warnings - front of cigarette packaging',
#  'Percentage of principal display area mandated to be covered by health warnings - back of cigarette packaging',
#  'Specific health warnings are mandated for cigarette packaging',
#  'Number of health warnings approved by the law for cigarette packaging',
#  'Health warnings appear on each cigarette package and any outside packaging and labelling used in the retail sale',
#  'Health warnings on cigarette packaging describe the harmful effects of tobacco use on health',
#  'Font style, font size and colour of health warnings are mandated for cigarette packaging',
#  'Health warnings on cigarette packaging must be rotated',
#  'Health warnings on cigarette packaging must be written in the principal language(s) of the country',
#  'Health warnings on cigarette packaging must include a photograph or graphic',
#  'Ban on deceitful terms on other smoked tobacco packaging',
#  'Percentage of principal display area mandated to be covered by health warnings - front and back of other smoked tobacco packaging',
#  'Percentage of principal display area mandated to be covered by health warnings - front of other smoked tobacco packaging',
#  'Specific health warnings are mandated for other smoked tobacco packaging',
#  'Number of health warnings approved by the law for other smoked tobacco packaging',
#  'Health warnings on other smoked tobacco packaging must be rotated',
#  'Percentage of principal display area mandated to be covered by health warnings - back of other smoked tobacco packaging',
#  'Health warnings appear on each other smoked tobacco package and any outside packaging and labelling used in the retail sale',
#  'Health warnings on other smoked tobacco packaging describe the harmful effects of tobacco use on health',
#  'Font style, font size and colour of health warnings are mandated for other smoked tobacco packaging',
#  'Health warnings on other smoked tobacco packaging must be written in the principal language(s) of the country',
#  'Health warnings on other smoked tobacco packaging must include a photograph or graphic',
#  'Ban on deceitful terms on smokeless tobacco packaging',
#  'Percentage of principal display area mandated to be covered by health warnings - front and back of smokeless tobacco packaging',
#  'Percentage of principal display area mandated to be covered by health warnings - front of smokeless tobacco packaging',
#  'Percentage of principal display area mandated to be covered by health warnings - back of smokeless tobacco packaging',
#  'Specific health warnings are mandated for smokeless tobacco packaging',
#  'Number of health warnings approved by the law for smokeless tobacco packaging',
#  'Health warnings appear on each smokeless tobacco package and any outside packaging and labelling used in the retail sale',
#  'Health warnings on smokeless tobacco packaging describe the harmful effects of tobacco use on health',
#  'Font style, font size and colour of health warnings are mandated for smokeless tobacco packaging',
#  'Health warnings on smokeless tobacco packaging must be rotated',
#  'Most sold brand of bidis - price in US$ at official exchange rates',
#  'Cheapest brand of bidis - currency reported',
#  'Cheapest brand of bidis - price in currency reported',
#  'Cheapest brand of bidis - price in US$ at official exchange rates',
#  'Health warnings on smokeless tobacco packaging must be written in the principal language(s) of the country',
#  'Health warnings on smokeless tobacco packaging must include a photograph or graphic',
#  'Billboard and outdoor advertising',
#  'International magazines and newspapers',
#  'International television and radio',
#  'Internet',
#  'Local magazines and newspapers',
#  'National television and radio',
#  'Point of sale',
#  'Subnational bans on tobacco advertising, promotion and sponsorship',
#  'Compliance with bans on direct advertising',
#  'Appearance of tobacco products in TV and/or films',
#  'Brand name of non-tobacco products used for tobacco product',
#  'Free distribution in mail or through other means',
#  'Non-tobacco products identified with tobacco brand names',
#  'Promotional discounts',
#  'Sponsored events',
#  'Compliance with bans on promotion and sponsorship',
#  'Most sold brand of cigarettes - currency reported',
#  'Most sold brand of cigarettes - price in currency reported',
#  'Most sold brand of cigarettes - price in US$ at official exchange rates',
#  'Cheapest brand of cigarettes - currency reported',
#  'Cheapest brand of cigarettes - price in currency reported',
#  'Cheapest brand of cigarettes - price in US$ at official exchange rates',
#  'Most sold brand of bidis - currency reported',
#  'Most sold brand of bidis - price in currency reported',
#  'Most sold brand of cigarettes - taxes as a % of price - ad valorem excise',
#  'Most sold brand of cigarettes - taxes as a % of price - import duties',
#  'Most sold brand of cigarettes - taxes as a % of price - specific excise',
#  'Most sold brand of cigarettes - taxes as a % of price - total tax',
#  'Cheapest brand of cigarettes - taxes as a % of price - ad valorem excise',
#  'Cheapest brand of cigarettes - taxes as a % of price - import duties',
#  'Cheapest brand of cigarettes - taxes as a % of price - specific excise',
#  'Cheapest brand of cigarettes - taxes as a % of price - total tax',
#  'Most sold brand of bidis - taxes as a % of price - ad valorem excise',
#  'Most sold brand of bidis - taxes as a % of price - import duties',
#  'Most sold brand of bidis - taxes as a % of price - specific excise',
#  'Most sold brand of bidis - taxes as a % of price - total tax',
#  'Cheapest brand of bidis - taxes as a % of price - ad valorem excise',
#  'Cheapest brand of bidis - taxes as a % of price - import duties',
#  'Cheapest brand of bidis - taxes as a % of price - specific excise',
#  'Cheapest brand of bidis - taxes as a % of price - total tax',
#  'Government objectives on tobacco control exist',
#  'National agency for tobacco control exists',
#  'Number of full-time equivalent staff in national agency',
#  'Annual budget for tobacco control in currency reported',
#  'Reported currency',
#  'Annual budget for tobacco control in US$ at official exchange rate',
#  'Budget year',
#  'Income level',
#  'Number of registered vehicles',
#  'Estimated number of road traffic deaths',
#  'Estimated road traffic death rate (per 100 000 population)',
#  'Existence of a national drink-driving law',
#  'Attribution of road traffic deaths to alcohol (%)',
#  'Existence of a national seat-belt law',
#  'Applicability of seat-belt law to all occupants',
#  'Existence of a national child-restraint law',
#  'Existence of national speed limits',
#  'Adaptation of national speed limit at a local level',
#  'Specification of national speed law by vehicle type',
#  'Existence of a national motorcycle helmet law',
#  'Applicability of national motorcycle helmet law to all road types',
#  'Applicability of national motorcycle helmet law to all engine types',
#  'Requirement of motorcycle helmet use to adhere to standard',
#  'Motorcycle helmet wearing rate (%)',
#  'Existence of a road safety lead agency',
#  'Existence of a national road safety strategy',
#  'Availability of funding for national road safety strategy',
#  'Existence of a national policy on walking and cycling',
#  'Existence of a national policy on public transport',
#  'Existence of road safety audit for all new roads',
#  'Existence of road safety audit for existing roads',
#  'Existence of mandatory vehicle insurance',
#  'Existence of a formal pre-hospital care system',
#  'Definition of drink-driving by BAC',
#  'Distribution of road traffic deaths by type of road user (%)',
#  'Blood Alcohol Concentration (BAC) limit for drivers',
#  'Seat-belt wearing rate (%)',
#  'Applicability of national motorcycle helmet law to all occupants',
#  'Type of driving tests for new drivers',
#  'Existence of a universal access telephone number for pre-hospital care',
#  'Maximum speed limits',
#  'Government unit for treatment',
#  'Government unit for alcohol and drugs: Location',
#  'Government unit for alcohol: Location',
#  'Government unit for drugs: Location',
#  'No government unit',
#  'Government unit for mental health/substance use: Location',
#  'Gross national income per capita (Atlas method)',
#  'Prevalence of HIV among adults aged 15 to 49 (%)',
#  'Year of survey of adults',
#  'Representativeness of survey of adults',
#  'Repeating interval for survey of adults (years)',
#  'Year of survey of youth',
#  'Representativeness of youth survey',
#  'Repeating interval for survey of youth (years)',
#  'Most sold brand of cigarettes - taxes as a % of price - value added tax',
#  'Most sold brand of cigarettes - taxes as a % of price - other taxes',
#  'Smear-positive tuberculosis case-detection rate (%)',
#  'Smear-positive tuberculosis treatment-success rate (%)',
#  'Population using solid fuels (%)',
#  'Age-standardized mortality rate by cause (per 100 000 population) - Communicable',
#  'Distribution of causes of death among children aged <5 years (%) - Prematurity',
#  'Distribution of causes of death among children aged <5 years (%) - Neonatal sepsis',
#  'Distribution of causes of death among children aged <5 years (%) - Congenital anomalies',
#  'Number of pharmaceutical personnel',
#  'Number of environment and public health workers',
#  'Density of pharmaceutical personnel (per 10 000 population)',
#  'Density of environment and public health workers (per 10 000 population)',
#  'Maternal mortality ratio (per 100 000 live births) - Country reported estimates',
#  'Number of reported cases of tuberculosis',
#  'Distribution of causes of death among children aged <5 years (%) - Birth asphyxia',
#  'Most sold brand of bidis - taxes as a % of price - value added tax',
#  'Most sold brand of bidis - taxes as a % of price - other taxes',
#  'Children aged <5 years wasted for age (%)',
#  'Prevalence of adults aged &#8805; 15 years who are pre-obese (%) (BMI 25.0-29.99)',
#  'Prevalence of adults aged &#8805; 15 years who are overweight (%) (BMI ? 25.0)',
#  'Prevalence of adults aged &#8805; 15 years who are in normal range (%) (BMI 18.5-24.99)',
#  'Prevalence of adults aged &#8805; 15 years who are underweight (%) (BMI <18.5)',
#  'Continued breastfeeding at 1 year (%)',
#  'Early initiation of breastfeeding (%)',
#  'Exclusive breastfeeding under 4 months (%)',
#  'Children ever breastfed (%)',
#  'Continued breastfeeding at 2 years (%)',
#  'Duration of any breastfeeding',
#  'Duration of exclusive breastfeeding',
#  'Introduction of solid, semi-solid or soft foods and breast milk (%)',
#  'Bottle feeding rate 0-11.9 months (%)',
#  'Bottle feeding rate 0-23.9 months (%)',
#  'Exclusive breastfeeding under 6 months (%)',
#  'BCG immunization coverage among 1-year-olds (%)',
#  'Polio (Pol3) immunization coverage among 1-year-olds (%)',
#  'Consumption of pure alcohol by type of beverage (%)',
#  'Consumption by type of alcoholic beverage - market share (%)',
#  'Recorded alcohol per capita (15+) consumption (in litres of pure alcohol)',
#  'Recorded alcohol per capita (15+) consumption (in litres of pure alcohol), three-year average',
#  'Estimate of five-year change in recorded alcohol per capita (15+) consumption',
#  'Total (recorded three-year average + unrecorded) per capita (15+) consumption (in litres of pure alcohol)',
#  'Drinkers only, total (recorded three-year average + unrecorded) per capita (15+) consumption (in litres of pure alcohol)',
#  'Tourist consumption (in litres of pure alcohol)',
#  'Unrecorded alcohol per capita (15+) consumption (in litres of pure alcohol)',
#  'Antiretroviral therapy coverage among people with HIV infection eligible for ART according to 2010 guidelines (%)',
#  'Antiretroviral therapy coverage among people with advanced HIV infection (%), WHO 2006 guidelines',
#  'Abstainers, lifetime (%)',
#  'Abstainers (15-19 years), lifetime (%)',
#  'Abstainers, past 12 months (%)',
#  'Abstainers (15-19 years), past 12 months (%)',
#  'Alcohol consumers (%), past 12 months',
#  'Former drinkers (%)',
#  'Heavy episodic drinking (population) past 30 days (%)',
#  'Heavy episodic drinking (drinkers only) past 30 days (%)',
#  'Patterns of drinking score',
#  'Age-standardized DALYs, alcohol use disorders, per 100,000',
#  'Age-standardized DALYs, breast cancer, per 100,000',
#  'Age-standardized DALYs, colon and rectum cancers, per 100,000',
#  'Age-standardized DALYs, diabetes mellitus, per 100,000',
#  'Age-standardized DALYs, drownings, per 100,000',
#  'Age-standardized DALYs, falls, per 100,000',
#  'Age-standardized DALYs, fires, per 100,000',
#  'Age-standardized DALYs, ischaemic heart disease, per 100,000',
#  'Age-standardized DALYs, liver cancer, per 100,000',
#  'Age-standardized DALYs, liver cirrhosis, per 100,000',
#  'Age-standardized DALYs, maternal conditions, per 100,000',
#  'Age-standardized DALYs, mouth and oropharynx cancer, per 100,000',
#  'Age-standardized DALYs, oesophagus cancer, per 100,000',
#  'Age-standardized DALYs, poisoning, per 100,000',
#  'Age-standardized DALYs, prematurity and low birth rate, per 100,000',
#  'Age-standardized DALYs, road traffic accidents, per 100,000',
#  'Age-standardized DALYs, self-inflicted injury, per 100,000',
#  'Age-standardized DALYs, other unintentional injuries, per 100,000',
#  'Age-standardized DALYs, violence, per 100,000',
#  'Age-standardized death rates, alcohol use disorders, per 100,000',
#  'Age-standardized death rates, breast cancer, per 100,000',
#  'Age-standardized death rates, colon and rectum cancers, per 100,000',
#  'Age-standardized death rates, diabetes mellitus, per 100,000',
#  'Age-standardized death rates, drownings, per 100,000',
#  'Age-standardized death rates, falls, per 100,000',
#  'Age-standardized death rates, fires, per 100,000',
#  'Age-standardized death rates, ischaemic heart disease, per 100,000',
#  'Age-standardized death rates, liver cancer, per 100,000',
#  'Age-standardized death rates, liver cirrhosis, per 100,000',
#  'Age-standardized death rates, maternal conditions, per 100,000',
#  'Age-standardized death rates, mouth and oropharynx cancer, per 100,000',
#  'Age-standardized death rates, oesophagus cancer, per 100,000',
#  'Age-standardized death rates, poisoning, per 100,000',
#  'Age-standardized death rates, prematurity and low birth rate, per 100,000',
#  'Age-standardized death rates, road traffic accidents, per 100,000',
#  'Age-standardized death rates, self-inflicted injury, per 100,000',
#  'Age-standardized death rates, other unintentional injuries, per 100,000',
#  'Age-standardized death rates, violence, per 100,000',
#  'Age-standardized death rates (15+ years), alcoholic liver disease, per 100,000',
#  'Age-standardized death rates (15+ years), liver cirrhosis, per 100,000',
#  'Age-standardized death rates (15+ years), poisoning, per 100,000',
#  'Age-standardized death rates (15+ years), road traffic accidents, per 100,000',
#  'Age-standardized death rates (15+ years), violence, per 100,000',
#  'Alcohol dependence (15+), 12 month prevalence (%) with 95%CI',
#  'Alcohol use disorders (15+), 12 month prevalence (%) with 95%CI',
#  'Alcoholic psychosis, incidence, per 100,000',
#  'Cautions and arrests for drink-driving, per 100,000 licensed drivers',
#  'Hospital discharges, alcohol-related injuries and poisoning, per 100,000',
#  'Hospital discharges, alcoholic liver disease, per 100,000',
#  'Perceived trend in alcohol-related harm and consequences',
#  'Treatment admissions (inpatient), alcohol dependence, per 100,000',
#  'Treatment admissions (inpatient), alcoholic psychosis, per 100,000',
#  'Road traffic crashes involving alcohol (15+), per 100,000',
#  'Road traffic crashes involving alcohol, % of all traffic crashes',
#  'Alcohol-related injury mortality, per 1,000',
#  'Alcohol-related disease mortality, per 100,000 (15+ years)',
#  'Alcoholic excise tax revenue as a per cent of government revenue',
#  'Annual revenues from alcohol excise tax in millions US$',
#  'Alcohol expenditure as a per cent of total household expenditure',
#  'Social costs of alcohol use in millions US$',
#  'Estimated number of people (all ages) living with HIV',
#  'Number of adults aged 15 and over living with HIV',
#  'Number of women aged 15 and over living with HIV',
#  'Number of children under 15 living with HIV',
#  'HIV prevalence rate among adults (15-49)',
#  'Number of deaths due to HIV/AIDS',
#  'Testing and counselling facilities, reported number',
#  'Testing and counselling facilities, estimated number per 100 000 adult population',
#  'Reported number of people receiving antiretroviral therapy',
#  'Reported number of people receiving antiretroviral therapy, month and year of report',
#  'Reported number of children receiving antiretroviral therapy',
#  'Reported number of children receiving antiretroviral therapy, month and year of report',
#  'Pregnant women tested for HIV, reported number',
#  'Pregnant women tested for HIV, estimated coverage (%)',
#  'Number of pregnant women living with HIV who received antiretrovirals for preventing mother-to-child transmission',
#  'Number of pregnant women living with HIV who received antiretrovirals for preventing mother-to-child transmission, reporting period',
#  'Number of people aged 15 years and over who received HIV testing and counselling, reported number',
#  'People aged 15 years and over who received HIV testing and counselling, estimated number per 1000 adult population',
#  'Number of people aged 15 years and over who received HIV testing and counselling, reporting period',
#  'Estimated percentage of pregnant women living with HIV who received antiretrovirals for preventing mother-to-child transmission',
#  'Estimated number of pregnant women living with HIV needing antiretrovirals for preventing mother-to-child transmission based on WHO methods',
#  'Estimated number of people eligible for antiretroviral therapy according to 2010 guidelines',
#  'Estimated number of children needing antiretroviral therapy based on WHO methods',
#  'Estimated antiretroviral therapy coverage among children',
#  'Adopted written national policy on alcohol',
#  'Alcoholic beverage legally defined',
#  'Alcohol use is banned',
#  'Surrogate alcohol consumption is a problem',
#  'National legislation to prevent illegal alcohol',
#  'Prevalence of adults aged &#8805; 15 years who are moderately and severely thin (BMI <17.0)',
#  'Prevalence of adults aged &#8805; 15 years who are severely thin (BMI <16.0)',
#  'Prevalence of adults aged &#8805; 15 years who are mildly thin (BMI 17.0-18.49)',
#  'Prevalence of adults aged &#8805; 15 years who are moderately thin (BMI 16.0-16.99)',
#  'Percentage of the children under 15 years with blood lead levels above 5ug/dl',
#  'Percentage of the children under 15 years with blood lead levels above 10ug/dl',
#  'Percentage of the adults (15+ years) with blood lead levels above 5ug/dl',
#  'Percentage of the adults (15+ years) with blood lead levels above 10ug/dl',
#  'Lead attributable deaths',
#  "Lead attributable DALYs ('000)",
#  "Lead attributable deaths per 100'000 capita",
#  "Lead attributable DALYs per 100'000 capita",
#  "Lead attributable DALYs ('000) in children under 5 years",
#  "Lead attributable DALYs per 100'000 children under 5 years",
#  'Percentage of children under 15 years exposed to second-hand smoke',
#  'Percentage of women (15+ years) exposed to second-hand smoke',
#  'Percentage of men (15+ years) exposed to second-hand smoke',
#  'Second-hand smoke attributable deaths',
#  "Second-hand smoke attributable DALYs ('000)",
#  "Second-hand smoke attributable deaths per 100'000 capita",
#  "Second-hand smoke attributable DALYs per 100'000 capita",
#  "Second-hand smoke attributable deaths ('000) in children under 5 years",
#  "Second-hand smoke  attributable deaths per 100'000 children under 5 years",
#  "Second-hand smoke attributable DALYs ('000) in children under 5 years",
#  "Second-hand smoke  attributable DALYs per 100'000 children under 5 years",
#  'Water, sanitation and hygiene attributable deaths',
#  "Water, sanitation and hygiene attributable deaths ('000) in children under 5 years",
#  "Water, sanitation and hygiene attributable deaths per 100'000 capita",
#  "Water, sanitation and hygiene  attributable deaths per 100'000 children under 5 years",
#  "Water, sanitation and hygiene attributable DALYs ('000)",
#  "Water, sanitation and hygiene attributable DALYs ('000) in children under 5 years",
#  "Water, sanitation and hygiene attributable DALYs per 100'000 capita",
#  "Water, sanitation and hygiene  attributable DALYs per 100'000 children under 5 years",
#  'Ambient air pollution attributable deaths',
#  'Ambient air pollution (Annual PM10 [ug/m3])',
#  "Percentage of the total population living in cities > 100'000 inhabitants",
#  'Ambient air pollution attributable deaths in children under 5 years',
#  "Ambient air pollution attributable deaths per 100'000 capita",
#  "Ambient air pollution  attributable deaths per 100'000 children under 5 years",
#  "Ambient air pollution attributable DALYs ('000)",
#  "Ambient air pollution attributable DALYs ('000) in children under 5 years",
#  "Ambient air pollution attributable DALYs per 100'000 capita",
#  "Ambient air pollution  attributable DALYs per 100'000 children under 5 years",
#  'Household air pollution attributable deaths',
#  'Household air pollution attributable deaths in children under 5 years',
#  "Household air pollution attributable deaths per 100'000 capita",
#  "Household air pollution  attributable deaths per 100'000 children under 5 years",
#  "Household air pollution attributable DALYs ('000)",
#  "Household air pollution attributable DALYs ('000) in children under 5 years",
#  "Household air pollution attributable DALYs per 100'000 capita",
#  "Household air pollution  attributable DALYs per 100'000 children under 5 years",
#  'Population using electricity as main cooking fuel (%)',
#  'Case detection rate for all forms of tuberculosis',
#  'Number of suspected meningitis deaths reported',
#  'Number of suspected meningitis cases reported',
#  'Number of deaths due to tuberculosis, excluding HIV',
#  'Number of prevalent tuberculosis cases',
#  'Number of incident tuberculosis cases',
#  'Incidence of tuberculosis (per 100 000 population) (HIV-positive cases)',
#  'Number of incident tuberculosis cases,  (HIV-positive cases)',
#  'Population using LPG as main cooking fuel (%)',
#  'Population using natural gas as main cooking fuel (%)',
#  'Population using biogas as main cooking fuel (%)',
#  'Population using kerosene as main cooking fuel (%)',
#  'Population using clean fuels (sum of)(%)',
#  'Population using coal as main cooking fuel (%)',
#  'Population using charcoal as main cooking fuel (%)',
#  'Population using wood as main cooking fuel (%)',
#  'Population using dung as main cooking fuel (%)',
#  'Population using crop waste as main cooking fuel (%)',
#  'Population using solid fuels (sum of) (%)',
#  'Population using others (non listed items) as main cooking fuel (%)',
#  'Population not cooking (%)',
#  'Missing information on cooking fuels (%)',
#  'Total survey respondents',
#  'Tuberculosis - new and relapse cases',
#  'Case detection rate for all forms of tuberculosis',
#  'Advertising restrictions on national television',
#  'Advertising restrictions on cable television',
#  'Advertising restrictions on national radio',
#  'Advertising restrictions on local radio',
#  'Advertising restrictions in print media',
#  'Advertising restrictions at cinemas',
#  'Advertising restrictions on billboards',
#  'Advertising restrictions at point-of-sale',
#  'Advertising restrictions on the internet',
#  'Restrictions on product placement on national television',
#  'Restrictions on product placement on cable television',
#  'Age limits on-premise service',
#  'Minimum legal drinking age',
#  'Legal blood alcohol concentration (BAC) limits',
#  'Random breath testing (RBT) use',
#  'Mandatory driver education for habitual offenders',
#  'Prices for alcoholic beverages (average, US$)',
#  'Trend in real price of alcoholic beverages relative to CPI over the past five years',
#  'Off-premise sales restrictions on days',
#  'Off-premise sales restrictions on hours',
#  'Off-premise sales restrictions on places',
#  'Off-premise sales restrictions on outlet density',
#  'Off-premise sales restrictions at specific events',
#  'Off-premise sales restrictions at petrol stations',
#  'On-premise sales restrictions on days',
#  'On-premise sales restrictions on hours',
#  'On-premise sales restrictions on places',
#  'On-premise sales restrictions on outlet density',
#  'On-premise sales restrictions at specific events',
#  'On-premise sales restrictions to intoxicated persons',
#  'Restrictions on sponsorship of sporting events',
#  'Restrictions on sponsorship of youth events',
#  'Restrictions on sales promotion from producers (parties, events)',
#  'Restrictions on sales promotion from retailers (sales below cost)',
#  'Restrictions on sales promotion from owners of pubs and bars (alcohol for free)',
#  'Government monopoly on production',
#  'Government monopoly on retail sales',
#  'Licence required for production',
#  'Licence required for retail sales',
#  'Excise tax as a per cent of the retail price of alcoholic beverages',
#  'Excise duty (average) per hectolitre in Euros',
#  'Excise tax as a per cent of the total retail price for 1 litre of pure alcohol',
#  'Duty paid or excise stamp on alcohol container',
#  'Excise tax on alcoholic beverages',
#  'Value-added tax (VAT) on alcohol (%)',
#  'Value-added tax (VAT), (%)',
#  'Restrictions on alcohol use in public places',
#  'Health warning labels on alcohol advertising',
#  'Health warning labels on alcohol containers',
#  'Monitoring',
#  'Treatment, services',
#  'Interventions, projects, training',
#  'Awareness activities',
#  'Information, education, prevention',
#  'Standard drink measures, in grams per unit',
#  'National drinking guidelines',
#  'Production in 1000s hectolitres',
#  'Imports in 1000s hectolitres',
#  'Sales of beer in 1000s hectolitres',
#  'Exports of beer (barley) in 1000s hectolitres',
#  'Perceived trend in production',
#  'Perceived trend in imports',
#  'Perceived trend in sales',
#  'Perceived trend in exports',
#  'Surveys, research',
#  'Counselling',
#  'Sales of wine in 1000s hectolitres',
#  'Sales of spirits in 1000s hectolitres',
#  'Exports of wine (grape) in 1000s hectolitres',
#  'Exports of spirits in 1000s hectolitres',
#  'New cases: Pulmonary, smear-positive',
#  'New cases: pulmonary smear-negative',
#  'New cases: pulmonary smear unknown/not done',
#  'New cases: extrapulmonary',
#  'New cases: other',
#  'Relapse cases (pre-2013 definition)',
#  'Retreatment cases: treatment after failure (pulmonary smear and/or culture positive)',
#  'Retreatment cases: treatment after default (pulmonary smear and/or culture positive)',
#  'Retreatment cases: other',
#  'Treatment history unknown',
#  'Number of deaths',
#  'Deaths per 1 000 live births',
#  'Distribution of causes of death among children aged < 5 years (%)',
#  'Laboratories providing tuberculosis diagnostic services using sputum smear microscopy (per 100 000 population)',
#  'Laboratories providing tuberculosis diagnostic services using culture (per 5 million population)',
#  'Laboratories providing drug susceptibility testing (DST) (per 5 million population)',
#  'Second-line drug susceptibility testing (DST) available',
#  'National Reference Laboratory (NRL)',
#  'Rifampicin used throughout treatment',
#  '% of patients treated with fixed-dose combinations (FDCs)',
#  'Paediatric formulations procured for TB patients',
#  'Treatment success rate for new pulmonary smear-negative and extrapulmonary tuberculosis cases',
#  'Treatment success rate: previously treated TB cases',
#  'BMI >= 25 (age-standardized estimate)',
#  'BMI >= 25 (crude estimate)',
#  'BMI >= 30 (age-standardized estimate)',
#  'BMI >= 30 (crude estimate)',
#  'Mean BMI (kg/m2) (age-standardized estimate)',
#  'Insufficiently active (age-standardized estimate)',
#  'Insufficiently active (crude estimate)',
#  'Climate change attributable deaths',
#  "Climate change attributable DALYs ('000)",
#  "Climate change attributable deaths per 100'000 capita",
#  "Climate change attributable DALYs per 100'000 capita",
#  "Climate change attributable deaths ('000) in children under 5 years",
#  "Climate change  attributable deaths per 100'000 children under 5 years",
#  "Climate change attributable DALYs ('000) in children under 5 years",
#  "Climate change  attributable DALYs per 100'000 children under 5 years",
#  'Occupational risk factors attributable deaths',
#  "Occupational risk factors attributable DALYs ('000)",
#  "Occupational risk factors attributable deaths per 100'000 capita",
#  "Occupational risk factors attributable DALYs per 100'000 capita",
#  'Deaths attributable to the environment',
#  'Age-standardized deaths attributable to the environment (per 100 000 population)',
#  'Disability-adjusted life years (DALYs) attributable to the environment',
#  'Age-standardized DALYs attributable to the environment (per 100 000 population)',
#  'Deaths attributable to the environment (%)',
#  'Disability-adjusted life years (DALYs) attributable to the environment (%)',
#  "Total environment attributable deaths ('000) in children under 5 years",
#  "Total environment  attributable deaths per 100'000 children under 5 years",
#  "Total environment attributable DALYs ('000) in children under 5 years",
#  "Total environment  attributable DALYs per 100'000 children under 5 years",
#  'Deaths attributable to the environment in children under 5 years (%)',
#  'DALYs attributable to the environment in children under 5 years (%)',
#  'UV radiation',
#  'UV radiation attributable deaths',
#  "UV radiation attributable DALYs ('000)",
#  "UV radiation attributable deaths per 100'000 capita",
#  "UV radiation attributable DALYs per 100'000 capita",
#  'Existence of Unit, Branch, or Dept. in Ministry of Health with responsibility for NCDs',
#  'Existence of operational policy/strategy/action plan for cardiovascular diseases',
#  'Existence of operational policy/strategy/action plan for cancer',
#  'Existence of operational policy/strategy/action plan for diabetes',
#  'Existence of operational policy/strategy/action plan for chronic respiratory diseases',
#  'Existence of operational policy/strategy/action plan to reduce the harmful use of alcohol',
#  'Existence of operational policy/strategy/action plan to reduce unhealthy diet related to NCDs',
#  'Existence of operational policy/strategy/action plan to reduce physical inactivity',
#  'Existence of operational policy/strategy/action plan to decrease tobacco use',
#  'Existence and scope of cancer registry',
#  'Existence of risk factor surveillance for selected risk factors (harmful alcohol use, diet, physical inactivity, and tobacco use)',
#  'Availability and stage of implementation of guidelines/protocols/standards for the management of diabetes',
#  'Availability and stage of implementation of guidelines/protocols/standards for the management of raised blood pressure / hypertension',
#  'General availability of cervical cytology at the primary health care level',
#  'General availability of acetic acid visualization at the primary health care level',
#  'General availability of colon cancer screening at the primary health care level',
#  'General availability of breast cancer screening (by palpation or mammogram) at the primary health care level',
#  'General availability of diabetes testing (by blood glucose measurement, OGTT, or HbA1c) at the primary health care level',
#  'General availability of electrocardiogram at the primary health care level',
#  'General availability of total cholesterol measurement at the primary health care level',
#  'General availability of peak flow measurement spirometry at the primary health care level',
#  'General availability of insulin in the public health sector',
#  'General availability of aspirin (100 mg) in the public health sector',
#  'General availability of metformin in the public health sector',
#  'General availability of glibenclamide in the public health sector',
#  'General availability of thiazide diuretics in the public health sector',
#  'General availability of ACE inhibitors in the public health sector',
#  'General availability of CC blockers in the public health sector',
#  'General availability of beta blockers in the public health sector',
#  'General availability of tamoxifen in the public health sector',
#  'General availability of statins in the public health sector',
#  'General availability of oral morphine in the public health sector',
#  'General availability of nicotine replacement therapy in the public health sector',
#  'General availability of salbutamol in the public health sector',
#  'General availability of prednisolone tabs in the public health sector',
#  'General availability of steroid inhalers in the public health sector',
#  'General availability of hydrocortisone injections in the public health sector',
#  'General availability of ipratropium bromide in the public health sector',
#  'General availability of retinal photocoagulation in the public health system',
#  'General availability of renal replacement therapy (by dialysis or transplantation) in the public health system',
#  'General availability of radiotherapy in the public health system',
#  'General availability of chemotherapy in the public health system',
#  'Existence of partnerships/collaborations for implementing key activities related to NCDs',
#  'Implementation of fiscal interventions to influence behaviour change',
#  'Earmarking of taxes from fiscal interventions to influence behaviour change used to fund health promotion programmes or a health promotion foundation',
#  'Occupational airborne particulates attributable deaths',
#  "Occupational airborne particulates attributable DALYs ('000)",
#  "Occupational airborne particulates attributable deaths per 100'000 capita",
#  "Occupational airborne particulates attributable DALYs per 100'000 capita",
#  'Occupational carcinogens attributable deaths',
#  "Occupational carcinogens attributable DALYs ('000)",
#  "Occupational carcinogens attributable deaths per 100'000 capita",
#  "Occupational carcinogens attributable DALYs per 100'000 capita",
#  "Occupational noise attributable DALYs ('000)",
#  "Occupational noise attributable DALYs per 100'000 capita",
#  'Occupational ergonomic stressors attributable deaths',
#  "Occupational ergonomic stressors attributable DALYs ('000)",
#  "Occupational ergonomic stressors attributable deaths per 100'000 capita",
#  "Occupational ergonomic stressors attributable DALYs per 100'000 capita",
#  'Occupational injuries attributable deaths',
#  "Occupational injuries attributable DALYs ('000)",
#  "Occupational injuries attributable deaths per 100'000 capita",
#  "Occupational injuries attributable DALYs per 100'000 capita",
#  'Number of nursing personnel',
#  'Number of physicians',
#  'Number of midwifery personnel',
#  'Number of pharmacists',
#  'Number of pharmaceutical technicians/assistants',
#  'Number of community health workers',
#  'Number of traditional birth attendants',
#  'Number of radiographers',
#  'Number of other health workers',
#  'Number of dental technicians/assistants',
#  'Number of health management & support workers',
#  'Number of environment and public health workers',
#  'Number of laboratory scientists',
#  'Number of laboratory technicians/assistants',
#  'Number of dentists',
#  'Number of traditional medicine practitioners',
#  'Number of medical assistants',
#  'Number of personal care workers',
#  'Number of pharmaceutical personnel',
#  'Number of laboratory health workers',
#  'Number of dentistry personnel',
#  'Number of community and traditional health workers',
#  'Number of other health workers',
#  'Number of nursing and midwifery personnel',
#  'Pharmaceutical personnel density (per 1000 population)',
#  'Physicians density (per 1000 population)',
#  'Laboratory health workers density (per 1000 population)',
#  'Dentistry personnel density (per 1000 population)',
#  'Community and traditional health workers density (per 1000 population)',
#  'Other health workers density (per 1000 population)',
#  'Environmental and public health workers density (per 1000 population)',
#  'Health management & support workers density (per 1000 population)',
#  'Nursing and midwifery personnel density (per 1000 population)',
#  'Raised blood pressure (SBP>=140 OR DBP>=90 OR on medication) (crude estimate)',
#  'Raised blood pressure (SBP>=140 OR DBP>=90 OR on medication) (age-standardized estimate)',
#  'Raised blood pressure (SBP>=140 OR DBP>=90) (crude estimate)',
#  'Raised blood pressure (SBP>=140 OR DBP>=90) (age-standardized estimate)',
#  'Mean systolic blood pressure (crude estimate)',
#  'Mean systolic blood pressure (age-standardized estimate)',
#  'Raised total cholesterol (>= 5.0 mmol/L) (crude estimate)',
#  'Raised total cholesterol (>= 5.0 mmol/L) (age-standardized estimate)',
#  'Mean Total Cholesterol (age-standardized estimate)',
#  'Mean Total Cholesterol (crude estimate)',
#  'Population',
#  'Total NCD Deaths',
#  'All NCDs, deaths per 100,000 (age-standardized estimate)',
#  'Cancers, deaths per 100,000 (age-standardized estimate)',
#  'Chronic respiratory diseases, deaths per 100,000 (age-standardized estimate)',
#  'Cardiovascular diseases and diabetes, deaths per 100,000 (age-standardized estimate)',
#  'NCD deaths under age 70 (percent of all NCD deaths)',
#  'Raised total cholesterol (&#8805; 6.2 mmol/L) (age-standardized estimate)',
#  'Raised total cholesterol (&#8805; 6.2 mmol/L) (crude estimate)',
#  'Stillbirth rate (per 1000 total births)',
#  'Mean fasting blood glucose (mmol/l) (age-standardized estimate)',
#  'Mean fasting blood glucose (mmol/l) (crude estimate)',
#  'Raised fasting blood glucose (>= 7.0 mmol/L or on medication) (crude estimate)',
#  'Raised fasting blood glucose (>=7.0 mmol/L or on medication)(age-standardized estimate)',
#  'Radiotherapy units (per 1 000 000 population)',
#  'Mean BMI (kg/m2) (crude estimate)',
#  'Number of new reported cases of Buruli ulcer',
#  'Dracunculiasis certification status of countries at the beginning of the year',
#  'Annual incidence of dracunculiasis cases',
#  'Number of new reported cases of human African trypanosomiasis (T.b. gambiense)',
#  'Number of new reported cases of human African trypanosomiasis (T.b. rhodesiense)',
#  'Coverage of antenatal care (4 visits)',
#  'Coverage of DTP3 immunization',
#  'Knowlege about sexual transmission of AIDS',
#  'HIV prevalence',
#  'Infant mortality per 1 000 live births',
#  'Coverage of measles immunization',
#  'Prevalence of obesity',
#  'Coverage of skilled birth attendance',
#  'Prevalence of (moderate or severe) stunting in children',
#  'Prevalence of current cigarette smoking',
#  'Under-five mortality per 1 000 live births',
#  'Population living in urban areas (%)',
#  'Population using improved drinking-water sources (%)',
#  'Status of endemicity for blinding trachoma',
#  'Population living in trachoma endemic areas',
#  'Population treated for active trachoma',
#  'Number of meningitis epidemic districts',
#  'Projections for total (recorded + unrecorded) alcohol per capita (15+) consumption',
#  'Slum population in urban areas (% of total population)',
#  'Contraceptive prevalence, among girls aged 15-19 (%)',
#  'Unmet need for family planning, among girls aged 15-19 (%)',
#  'Births attended by skilled health personnel, among girls aged 15-19 (%)',
#  'Antenatal care coverage - at least one visit, among girls aged 15-19 (%)',
#  "Handwashing with soap after cleaning child's stool (%)",
#  'Handwashing with soap after using the toilet (%)',
#  'Point prevalence (%), alcohol use disorders, 15+ years',
#  'Point prevalence (%), drug use disorders, 15+ years',
#  'Age-standardized death rates, alcohol and drug use disorders, per 100 000',
#  'Age-standardized death rates, drug use disorders, per 100 000',
#  'Age-standardized DALYs, alcohol and drug use disorders, per 100 000',
#  'Age-standardized DALYs, drug use disorders, per 100 000',
#  'Psychoactive substance causing entry into treatment',
#  'Age-standardized DALYs, cerebrovascular disease, per 100,000',
#  'Age-standardized death rates, cerebrovascular disease, per 100,000',
#  'Epidemiological data collection system for substance use disorders',
#  'Service delivery data collection system for substance use disorders',
#  'National survey on substance use among children and adolescents',
#  'Data on substance use disorders disseminated in national annual reports',
#  'Substance use policy at the national level',
#  'Substance use policy at the national level, level of integration',
#  'Policy documents on the pharmacological treatment of substance use disorders',
#  'Guidelines on the pharmacological treatment of substance use disorders',
#  'Legislative provision for treatment and rehabilitation of substance use disorders',
#  'Legislative provision for compulsory treatment',
#  'Drug courts',
#  'Programmes diverting clients from the justice system towards treatment',
#  ...]

# %%
conc = pd.DataFrame([], columns=['concept', 'concept_type', 'description'])

# %%
conc['concept'] = indi_list
conc['description'] = indi_desc_list

# %%
conc['concept_type'] = 'measure'

# %%
conc.to_csv('../../ddf--concepts--continuous.csv', index=False)

# %%
# !open .

# %%
inds = pd.read_csv('all_indicators.csv')

# %%
lens = []

for i in conc['concept'].values:
    path = os.path.join('source', i+'.csv')
    if os.path.exists(path):
        try:
            df = pd.read_csv(path)
            lens.append(len(df))
        except:
            print(path)
            lens.append(-1)
    else:
        lens.append(np.nan)
# Out:
# source/HRH_20.csv
# source/HRH_27.csv
# source/DEVICES12.csv
# source/DEVICES21.csv
# source/DEVICES22.csv
# source/WHS9_CBR.csv
# source/PerctestedANC.csv
# source/PercposANC.csv
# source/PercposSW.csv
# source/PercposMSM.csv
# /usr/local/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# source/MORT_700.csv
# source/GHE_DALYNUM.csv
# source/GHE_YLDNUM.csv
# source/GHE_YLDRATE.csv
# source/GHE_YLLNUM.csv
# source/GHE_YLLRATE.csv
# source/PerctreatedANC.csv
# source/csection.csv
# source/EMFLIMITPOWERDENSITY.csv

# %%
dtype = []
key = []

for i in conc['concept'].values:
    path = os.path.join('source', i+'.csv')
    if os.path.exists(path):
        try:
            df = pd.read_csv(path)
        except:
            dtype.append(np.nan)
            key.append(np.nan)
            continue
        
        if len(df) == 0:
            dtype.append(np.nan)
            key.append(np.nan)
            continue
            
        if np.all(df['Numeric'].isnull()) == True:
            dtype.append('str')
        else:
            dtype.append('number')
            
        if 'COUNTRY' in df.columns:
            key.append('country')
        elif 'REGION' in df.columns:
            key.append('region')
        else:
            key.append('unknow')
        
    else:
        dtype.append(np.nan)
        key.append(np.nan)
# Out:
# /usr/local/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
conc['length'] = lens

# %%
conc['data_key'] = key
conc['data_type'] = dtype

# %%
conc[['concept', 'concept_type', 'length', 'data_key', 'data_type', 'description']].to_csv('all_indicators.csv', index=False)

# %%
conc[conc['length'] == -1]['concept'].values
# Out:
# array(['HRH_20', 'HRH_27', 'DEVICES12', 'DEVICES21', 'DEVICES22',
#        'WHS9_CBR', 'PerctestedANC', 'PercposANC', 'PercposSW',
#        'PercposMSM', 'MORT_700', 'GHE_DALYNUM', 'GHE_YLDNUM',
#        'GHE_YLDRATE', 'GHE_YLLNUM', 'GHE_YLLRATE', 'PerctreatedANC',
#        'csection', 'EMFLIMITPOWERDENSITY'], dtype=object)

# %%
inds['data_type'].unique()
# Out:
# array(['number', nan], dtype=object)

# %%
k = np.random.choice(inds['concept'].values)
print(k)
# Out:
# Camp_mat_tested

# %%
k = 'MDG_0000000018'

# %%
conc[conc['concept'] == k]['description']
# Out:
# 13    Deaths due to tuberculosis among HIV-positive ...
# Name: description, dtype: object

# %%
df = pd.read_csv('source/{}.csv'.format(k))
df.sort_values(by=['REGION', 'YEAR'])
# Out:
#                GHO PUBLISHSTATE  YEAR   REGION WORLDBANKINCOMEGROUP  \
# 10  MDG_0000000018    PUBLISHED  2007      AFR                  NaN
# 9   MDG_0000000018    PUBLISHED  2007      AMR                  NaN
# 4   MDG_0000000018    PUBLISHED  2007      EMR                  NaN
# 8   MDG_0000000018    PUBLISHED  2007      EUR                  NaN
# 0   MDG_0000000018    PUBLISHED  2007   GLOBAL                  NaN
# 1   MDG_0000000018    PUBLISHED  2007  NOTSPEC                WB_HI
# 2   MDG_0000000018    PUBLISHED  2007  NOTSPEC                WB_LI
# 3   MDG_0000000018    PUBLISHED  2007  NOTSPEC      WB_WORLD_INCOME
# 6   MDG_0000000018    PUBLISHED  2007  NOTSPEC               WB_UMI
# 11  MDG_0000000018    PUBLISHED  2007  NOTSPEC               WB_LMI
# 7   MDG_0000000018    PUBLISHED  2007     SEAR                  NaN
# 5   MDG_0000000018    PUBLISHED  2007      WPR                  NaN
#
#     Display Value  Numeric   Low  High  Comments
# 10           47.6     47.6  47.6  47.6       NaN
# 9             0.9      0.9   0.9   0.9       NaN
# 4             1.4      1.4   1.4   1.4       NaN
# 8             0.9      0.9   0.9   0.9       NaN
# 0             6.8      6.8   6.8   6.8       NaN
# 1             0.1      0.1   0.1   0.1       NaN
# 2            21.1     21.1  21.1  21.1       NaN
# 3             6.8      6.8   6.8   6.8       NaN
# 6            12.9     12.9  12.9  12.9       NaN
# 11            2.1      2.1   2.1   2.1       NaN
# 7             2.3      2.3   2.3   2.3       NaN
# 5             0.8      0.8   0.8   0.8       NaN

# %%
ddf.SEARCH_PATH = '/Users/semio/src/work/Gapminder/'

# %%
ddf.ddf_datapoint('ddf--gapminder--systema_globalis', 'tb_with_hivplus_number_of_new_cases_estimated').query('geo== "ago"')
# Out:
#     geo  tb_with_hivplus_number_of_new_cases_estimated  time
# 72  ago                                            595  1990
# 73  ago                                            772  1991
# 74  ago                                            992  1992
# 75  ago                                           1262  1993
# 76  ago                                           1585  1994
# 77  ago                                           1963  1995
# 78  ago                                           2399  1996
# 79  ago                                           2890  1997
# 80  ago                                           3434  1998
# 81  ago                                           4030  1999
# 82  ago                                           4668  2000
# 83  ago                                           5318  2001
# 84  ago                                           5985  2002
# 85  ago                                           6653  2003
# 86  ago                                           7304  2004
# 87  ago                                           7931  2005
# 88  ago                                           8523  2006
# 89  ago                                           9089  2007

# %%
df['Display Value'].unique()
# Out:
# array(['Not applicable', 'Not available', 'No', 'Yes'], dtype=object)

# %%
np.all(df['Numeric'].isnull()) == True
# Out:
# False

# %%
df['Numeric'].unique() # 所有indicator都是有numeric数据的。那display Value怎么储存？
# Out:
# array([  18.,   56.,   44.,   50.,   62.,   24.,   87.,   91.,   75.,
#          28.,   29.,   58.,   73.,   78.,   48.,   69.,   57.,   33.,
#          27.,   26.,   63.,   55.,   68.,   40.,   66.,   79.,   67.,
#          46.,   30.,   64.,   43.,   74.,  100.,   92.,   83.,   88.,
#          61.,   71.,   99.,   90.,   86.,   85.,   81.,   60.,   97.,
#          70.,   89.,   93.,   72.,   84.,   35.,   95.,   45.,   96.,
#          76.,    6.,   65.,   82.,   94.,   77.,   80.,   59.,   98.,
#          47.,   52.,   51.,   42.,   nan])

# %%
conc.columns
# Out:
# Index(['concept', 'concept_type', 'description', 'length', 'data_key',
#        'data_type'],
#       dtype='object')

# %%
# data points

# %%
conc = pd.read_csv('all_indicators.csv')

# %%
for i, row in conc[(conc['length'] > 0) & (conc['data_key'] == 'country')].iterrows():
    cid =  to_concept_id(row['concept'])
    df = pd.read_csv(os.path.join('source', row['concept']+'.csv'))   
    df.columns = list(map(to_concept_id, df.columns))    
    path = os.path.join('../', 'ddf--datapoints--{}--by--country--year.csv'.format(cid))
    
    if 'year' not in df.columns:
#         print(cid)
        continue
    
    if row['data_type'] == 'number':
        df = df[['country', 'year', 'numeric']]
    else:
        df = df[['country', 'year', 'display_value']]
        
    df.columns = [['country', 'year', cid]]
    
    df.sort_values(by=['country', 'year']).dropna(how='any').to_csv(path, index=False)

# %%
conc['concept'] = conc['concept'].map(to_concept_id)

# %%
conc.query()

# %%
# country

# %%
c_url = 'http://apps.who.int/gho/athena/api/COUNTRY'

cr = requests.get(c_url)

# %%
cp = xmltodict.parse(cr.content)

# %%
c = {}

for i in cp['GHO']['Metadata']['Dimension']['Code']:
    
    attrs = i['Attr']
    
    c[i['@Label']] = dict([(attr['@Category'], attr['Value']['Display']) for attr in attrs])

# %%
cdf = pd.DataFrame.from_dict(c, orient='index')

# %%
cdf.index.name = 'country'

cdf.reset_index().to_csv('all_countries.csv', index=False)

# %%
cdf = cdf.reset_index()

# %%
# !open .

# %%
cdf[['country', 'SHORTNAMEES']].rename(columns={'SHORTNAMEES': 'name'}).to_csv('../ddf--entities--country.csv', index=False)

# %%
# concepts

# %%
not_conc = ["m_survey_title_adult",
"m_svy_national_adult",
"m_svy_age_adult",
"m_def_1_text_adult",
"m_def_1_prev_adult",
"m_def_2_text_adult",
"m_def_2_prev_adult",
"m_smkless_survey_title_adult",
"m_smkless_svy_national_adult",
"m_smkless_age_range_adult",
"m_smkless_def_text_adult",
"m_smkless_prev_adult",
"m_survey_title_youth",
"m_svy_national_youth",
"m_svy_age_youth",
"m_def_1_text_youth",
"m_def_1_prev_youth",
"m_def_2_text_youth",
"m_def_2_prev_youth",
"m_smkless_survey_title_youth",
"m_smkless_svy_national_youth",
"m_smkless_age_range_youth",
"m_smkless_def_text_youth",
"m_smkless_prev_youth",
"camp_nat",
"camp_gov_prog",
"camp_mat_tested",
"camp_aud_research",
"camp_tv_radio",
"camp_media_planning",
"camp_news",
"camp_airtime",
"camp_eval_impact",
"rev_type",
"rev_year",
"rev_curr",
"rev_excise",
"rev_vat",
"rev_imp_other",
"rev_govt_total",
"r_excise_type",
"r_excise_uniform_varied",
"r_excise_specific_reliance",
"r_excise_min_specific",
"r_excise_retail_price_base",
"r_afford_less",
"r_afford_tax_auto_adjust",
"r_admin_tax_stamps",
"r_admin_duty_free_limited",
"r_admin_duty_free_allowance",
"r_excise_proportion",
"r_afford_gdp",
"r_afford_price_dispersion"]

# %%
conc_ = conc.copy()

conc_['concept'] = conc_['concept'].map(to_concept_id)

# %%
conc_ = conc_.query('concept not in {}'.format(not_conc))

# %%
conc_ = conc_.query('length > 0')

# %%
condf = conc_[['concept', 'concept_type', 'description']]

# %%
condf = condf.rename(columns={'description': 'name'})

# %%
condf = condf.append(pd.DataFrame([['name', 'string', 'Name'], 
                                   ['year', 'time', 'Year'], 
                                   ['country', 'entity_domain', 'Country']], columns=condf.columns))

# %%
condf.to_csv('../ddf--concepts.csv', index=False)

# %%
from ddf_utils.index import create_index_file

# %%
create_index_file('../')
# Out:
#              key         value  \
# 0        concept  concept_type
# 1        concept          name
# 0   country,year         air_1
# 0   country,year        air_10
# 0   country,year        air_11
# 0   country,year        air_12
# 0   country,year        air_13
# 0   country,year        air_14
# 0   country,year        air_15
# 0   country,year        air_16
# 0   country,year        air_17
# 0   country,year        air_18
# 0   country,year         air_2
# 0   country,year       air_2_1
# 0   country,year         air_3
# 0   country,year       air_3_1
# 0   country,year         air_4
# 0   country,year        air_40
# 0   country,year         air_5
# 0   country,year         air_6
# 0   country,year         air_7
# 0   country,year         air_8
# 0   country,year         air_9
# 0   country,year          anc1
# 0   country,year         anc15
# 0   country,year          anc4
# 0   country,year         anc45
# 0   country,year         asfr1
# 0   country,year          bcgv
# 0   country,year         bp_03
# ..           ...           ...
# 0   country,year      whs7_147
# 0   country,year      whs7_149
# 0   country,year      whs7_150
# 0   country,year      whs7_156
# 0   country,year      whs8_110
# 0   country,year       whs9_85
# 0   country,year       whs9_86
# 0   country,year       whs9_87
# 0   country,year       whs9_88
# 0   country,year       whs9_89
# 0   country,year       whs9_90
# 0   country,year       whs9_91
# 0   country,year       whs9_92
# 0   country,year       whs9_93
# 0   country,year       whs9_94
# 0   country,year       whs9_95
# 0   country,year       whs9_96
# 0   country,year       whs9_97
# 0   country,year      whs9_cdr
# 0   country,year       whs9_cs
# 0   country,year       whs_pbr
# 0   country,year         wsh_1
# 0   country,year         wsh_2
# 0   country,year         wsh_3
# 0   country,year         wsh_4
# 0   country,year         wsh_5
# 0   country,year         wsh_6
# 0   country,year         wsh_7
# 0   country,year         wsh_8
# 0        country          name
#
#                                                 file
# 0                                  ddf--concepts.csv
# 1                                  ddf--concepts.csv
# 0      ddf--datapoints--air_1--by--country--year.csv
# 0     ddf--datapoints--air_10--by--country--year.csv
# 0     ddf--datapoints--air_11--by--country--year.csv
# 0     ddf--datapoints--air_12--by--country--year.csv
# 0     ddf--datapoints--air_13--by--country--year.csv
# 0     ddf--datapoints--air_14--by--country--year.csv
# 0     ddf--datapoints--air_15--by--country--year.csv
# 0     ddf--datapoints--air_16--by--country--year.csv
# 0     ddf--datapoints--air_17--by--country--year.csv
# 0     ddf--datapoints--air_18--by--country--year.csv
# 0      ddf--datapoints--air_2--by--country--year.csv
# 0    ddf--datapoints--air_2_1--by--country--year.csv
# 0      ddf--datapoints--air_3--by--country--year.csv
# 0    ddf--datapoints--air_3_1--by--country--year.csv
# 0      ddf--datapoints--air_4--by--country--year.csv
# 0     ddf--datapoints--air_40--by--country--year.csv
# 0      ddf--datapoints--air_5--by--country--year.csv
# 0      ddf--datapoints--air_6--by--country--year.csv
# 0      ddf--datapoints--air_7--by--country--year.csv
# 0      ddf--datapoints--air_8--by--country--year.csv
# 0      ddf--datapoints--air_9--by--country--year.csv
# 0       ddf--datapoints--anc1--by--country--year.csv
# 0      ddf--datapoints--anc15--by--country--year.csv
# 0       ddf--datapoints--anc4--by--country--year.csv
# 0      ddf--datapoints--anc45--by--country--year.csv
# 0      ddf--datapoints--asfr1--by--country--year.csv
# 0       ddf--datapoints--bcgv--by--country--year.csv
# 0      ddf--datapoints--bp_03--by--country--year.csv
# ..                                               ...
# 0   ddf--datapoints--whs7_147--by--country--year.csv
# 0   ddf--datapoints--whs7_149--by--country--year.csv
# 0   ddf--datapoints--whs7_150--by--country--year.csv
# 0   ddf--datapoints--whs7_156--by--country--year.csv
# 0   ddf--datapoints--whs8_110--by--country--year.csv
# 0    ddf--datapoints--whs9_85--by--country--year.csv
# 0    ddf--datapoints--whs9_86--by--country--year.csv
# 0    ddf--datapoints--whs9_87--by--country--year.csv
# 0    ddf--datapoints--whs9_88--by--country--year.csv
# 0    ddf--datapoints--whs9_89--by--country--year.csv
# 0    ddf--datapoints--whs9_90--by--country--year.csv
# 0    ddf--datapoints--whs9_91--by--country--year.csv
# 0    ddf--datapoints--whs9_92--by--country--year.csv
# 0    ddf--datapoints--whs9_93--by--country--year.csv
# 0    ddf--datapoints--whs9_94--by--country--year.csv
# 0    ddf--datapoints--whs9_95--by--country--year.csv
# 0    ddf--datapoints--whs9_96--by--country--year.csv
# 0    ddf--datapoints--whs9_97--by--country--year.csv
# 0   ddf--datapoints--whs9_cdr--by--country--year.csv
# 0    ddf--datapoints--whs9_cs--by--country--year.csv
# 0    ddf--datapoints--whs_pbr--by--country--year.csv
# 0      ddf--datapoints--wsh_1--by--country--year.csv
# 0      ddf--datapoints--wsh_2--by--country--year.csv
# 0      ddf--datapoints--wsh_3--by--country--year.csv
# 0      ddf--datapoints--wsh_4--by--country--year.csv
# 0      ddf--datapoints--wsh_5--by--country--year.csv
# 0      ddf--datapoints--wsh_6--by--country--year.csv
# 0      ddf--datapoints--wsh_7--by--country--year.csv
# 0      ddf--datapoints--wsh_8--by--country--year.csv
# 0                         ddf--entities--country.csv
#
# [1248 rows x 3 columns]
